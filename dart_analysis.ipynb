# %%
import OpenDartReader
from dotenv import load_dotenv
import os 
import pandas as pd

load_dotenv()
api_key =  os.environ.get('OpenDartReader_key')
dart = OpenDartReader(api_key)

AWS_KEY = os.environ.get('AWS_KEY')
AWS_SECRET = os.environ.get('AWS_SECRET')
tableau_key = os.environ.get('tableau_red')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 20)

# %%
def readFromPrestoDB(sql_command):
    ''' Hive DB에서 데이터 로딩 '''
    try:
        from pyhive import presto
        import pandas as pd

        presto_conn = presto.connect(
            host = "presto-internal.dp.zigbang.net",
            port = 80,
            username = "biglabred", catalog = "hive", schema = ""
        )

        df = pd.read_sql(sql_command, presto_conn)

        presto_conn.close()
        return df
    
    except:
        print('Failed to read data from hive DB')

# %%
def get_sql(AWS_KEY, AWS_SECRET, sql_command):
    import cryptocode
    import pymysql
    import s3fs
    # 암호화된 태블로 DB 접속키 로딩
    # 암호화된 태블로 DB 접속키 로딩
    fs = s3fs.S3FileSystem(anon=False, key=AWS_KEY, secret=AWS_SECRET)
    with fs.open("s3://zigbang-mlops/models/red/red_encrypted.txt", mode="r") as f:
        key = f.readline()

    conn = pymysql.connect(
        #host="biglab.c3svvjp5iqfn.ap-northeast-1.rds.amazonaws.com", port=3306,
        host="rds-red-w.zigbang.io", port=3306,
        user="zigbang_tableau", passwd=tableau_key, #cryptocode.decrypt(key, AWS_SECRET),
        db="tableau", charset="utf8"
    )
    cursor = conn.cursor() 
    cursor.execute(sql_command)
    result = pd.DataFrame(cursor.fetchall())

    num_fileds = len(cursor.description)
    field_names = [i[0] for i in cursor.description]
    result.columns = field_names

    conn.close()
        
    return result

# %%
def load_xml_to_dataframe(response, keyword):
    import bs4 as bs
    import urllib.request
    soup = bs.BeautifulSoup(response_xml,'xml')
    
    rows = soup.find_all(keyword)
    columns = rows[0].find_all()
    
    rowList = []
    nameList = []
    columnList = []

    rowsLen = len(rows)
    columnsLen = len(columns)

    for i in range(0, rowsLen):
        columns = rows[i].find_all()

        for j in range(0, columnsLen):
            if i == 0:
                nameList.append(columns[j].name) #header
            eachColumn = columns[j].text #value
            columnList.append(eachColumn)
        rowList.append(columnList)
        columnList = []    # 다음 row의 값을 넣기 위해 비워준다

    result = pd.DataFrame(rowList, columns=nameList)
    return result

# %%
def ExportDataFrameGspread(googlespread_link, sheetname, dataframe, AWS_KEY, AWS_SECRET):    
    import gspread
    from oauth2client.service_account import ServiceAccountCredentials
    import s3fs
    import numpy as np

    scope = ['https://spreadsheets.google.com/feeds',
     'https://www.googleapis.com/auth/drive']
    fs = s3fs.S3FileSystem(anon=False, key=AWS_KEY, secret=AWS_SECRET)
    key_file_name = "gspreadkey.json"
    fs.download(f"s3://zigbang-mlops/models/red/{key_file_name}", key_file_name)

    credentials = ServiceAccountCredentials.from_json_keyfile_name(key_file_name, scope)
    gc = gspread.authorize(credentials)
    spreadsheet_url= googlespread_link
    doc = gc.open_by_url(spreadsheet_url)

    worksheet = doc.worksheet(sheetname)
    worksheet.clear()  #clear selected worksheet before export data frame
    
    dataframe.replace([np.inf, -np.inf], np.nan, inplace=True)
    dataframe.fillna('', inplace=True)
    worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())
           
    if os.path.exists("gspreadkey.json"):
        os.remove("gspreadkey.json")

# %%
def push_into_tableau_DB(data, AWS_KEY, AWS_SECRET, table_name, sql_create, replace=False):
    import cryptocode
    import pymysql
    import s3fs
    
    # 암호화된 태블로 DB 접속키 로딩
    fs = s3fs.S3FileSystem(anon=False, key=AWS_KEY, secret=AWS_SECRET)
    with fs.open("s3://zigbang-mlops/models/red/red_encrypted.txt", mode="r") as f:
        key = f.readline()
    
    # 태블로 DB에 접속하는 코드
    tableau_conn = pymysql.connect(
        host="rds-red-w.zigbang.io", port=3306,
        user="zigbang_tableau", passwd=cryptocode.decrypt(key, AWS_SECRET),
        db="tableau", charset="utf8"
    )
    cur = tableau_conn.cursor()

    # table_name이 존재하는지 체크하는 코드
    exist = cur.execute(f"SHOW TABLES LIKE '{table_name}'")
    
    if not exist:
        # table_name이 없다면 data 기반으로 생성하는 코드
        cur.execute(sql_create)
        
    # NULL 데이터 처리
    data = data.where(pd.notnull(data),"")
    
    # run_date 추가
    #data["run_date"] = datetime.now(timezone('Asia/Seoul')).strftime("%Y-%m-%d %H:%M:%S")
    
    # Replace할 경우 기존 데이터 삭제
    if replace:
        cur.execute(f"DELETE FROM {table_name}")
    
    # 데이터를 INSERT 하는 코드
    columns = ", ".join(data.columns)
    values = '('+', '.join(['%s']*len(data.columns))+')'
    
    print(columns, values)
    statement = "INSERT INTO " + table_name + " (" + columns + ") VALUES " + values
    insert = [tuple(x) for x in data.values]
    cur.executemany(statement, insert)
    
    # Commit 및 접속 종료
    cur.execute("COMMIT")
    tableau_conn.close()

# %%
def readFromGspread(googlespread_link, sheetname, AWS_KEY, AWS_SECRET):
    ''' 구글 스프레드시트에서 데이터 로딩 '''
    import gspread
    from oauth2client.service_account import ServiceAccountCredentials
    import s3fs
    
    scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
    fs = s3fs.S3FileSystem(anon=False, key=AWS_KEY, secret=AWS_SECRET)
    key_file_name = "gspreadkey.json"
    fs.download(f"s3://zigbang-mlops/models/red/{key_file_name}", key_file_name)
    #with fs.open("s3://zigbang-mlops/models/red/{key_file_name}}",key_file_name, mode="r") as f:
    #    key = f.readline()
    
    credentials = ServiceAccountCredentials.from_json_keyfile_name(key_file_name, scope)
    gc = gspread.authorize(credentials)
    spreadsheet_url= googlespread_link
    doc = gc.open_by_url(spreadsheet_url)
    
    df = pd.DataFrame.from_records(doc.worksheet(sheetname).get_all_values())
    
    df.columns = df.iloc[0]
    df = df[1:]
    
    import os
    os.remove(key_file_name)
              
    return df

# %% [markdown]
# ## 데이터 불러오기

# %% [markdown]
# #### 기업개요 및 주소 정보

# %%
df_company = readFromPrestoDB('''
select * from 
(
select "고유번호", "정식명칭", "영문명칭", "종목명", "종목코드","법인구분", "법인등록번호",
"사업자등록번호", "주소", "업종코드", "업종명", "설립일",
"결산월", "created_at", "updated_at" from hive.ods.biglab_disclosure_company_overview
where "법인등록번호" !=''  and  "종목코드" != ''
) X
left join 
(
select * from
hive.ods.biglab_disclosure_company_address 
) Y
on X."주소" = Y."주소" 
'''
)

#법인등록번호가 null값인 것은 해외소재주소지로 제외 
#종목코드가 있는 상장사로 필터

# %% [markdown]
# #### 기업 분류 기준

# %%
url_industry_categorization = 'https://docs.google.com/spreadsheets/d/1N8iOHx1M8PLqlGiA2tgOKl-AFoCNw3Ew9bwHMMhBIIU/edit#gid=201266420'
df_industry_categorization = readFromGspread(url_industry_categorization, '표준산업대분류', AWS_KEY, AWS_SECRET)
df_industry_categorization = df_industry_categorization[['산업대분류', 'range_start', 'range_end']]

#df_industry_categorization = readFromGspread(url_industry_categorization, '표준산업분류', AWS_KEY, AWS_SECRET) 
#df_industry_categorization  = df_industry_categorization.CODE.astype(str).str.zfill(2)

# %% [markdown]
# #### 직원현황 공시정보

# %%
df_employee.정규직수.str

# %%
df_employee = readFromPrestoDB('''
select * from  hive.ods.biglab_disclosure_business_report_employee_summary    
where "보고서코드" ='11011'                         
''')
cols = ['정규직수', '합계', '연간급여총액', '1인평균급여액']
for col in cols:
    df_employee[col] = np.where(df_employee[col]=='-', 0, df_employee[col])
    df_employee[col] = pd.to_numeric(df_employee[col], errors='coerce')
df_employee.dropna()   #데이터 중 숫자가 아닌데 숫자로 들어간 데이터는 제외한다. 예시: 연간급여총액=="####################"으로 되어있는경우 위의 to_numeric coerce로 nan값을 주게 되고 이를 레코드에서 드랍 시킨다.
# Out:
# 정규직수
# 합계
# 연간급여총액
# 1인평균급여액
# Empty DataFrame
# Columns: [id, 고유번호, 사업연도, 보고서코드, 접수번호, 법인구분, 법인명, 사업부문, 성별, 개정전직원수정규직, 개정전직원수계약직, 개정전직원수기타, 정규직수, 정규직단시간근로자수, 계약직수, 계약직단시간근로자수, 합계, 평균근속연수, 연간급여총액, 1인평균급여액, 비고, created_at, updated_at]
# Index: []

# %% [markdown]
# #### 사업보고서 공시 자료 api 호출 중. (추후 태블로 DB에서 가져올 예정)

# %% [markdown]
# df_financial_stat = readFromPrestoDB('''
# select * from hive.ods.biglab_disclosure_financial_statement
# where "재무제표종류"='재무상태표, 유동/비유동법-연결재무제표'  -- '재무상태표, 유동/비유동법-별도재무제표'
# and "보고서종류"='사업보고서'
# and "항목코드"='ifrs-full_Assets' or "항목코드"= 'ifrs_Assets' -- 자산총계
# ''')

# %%
# %%time

api_key =  os.environ.get('OpenDartReader_key')
dart = OpenDartReader(api_key)
df = pd.DataFrame()
for yr in range(2018, 2020):
    for stock_code in df_company.종목코드:
        try:
            row = dart.finstate(corp=stock_code, bsns_year=yr , reprt_code='11011')
            if  row.shape!=(0,0):  #013 :조회된 데이타가 없습니다 일 경우에는 쉐입이 (0,0) 이 됨..
                df = df.append(row)
            else:
                print("해당보고서가 없습니다: ",stock_code, "  year:", yr)
                continue 
        except:
            row = []
            continue
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  055000   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032600   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  062730   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  034660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  035010   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  054010   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  093820   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  031800   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  003020   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045820   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  058550   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  047600   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  122290   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  035500   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  023670   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  006070   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  080140   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  025460   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  098150   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  007830   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  053470   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  000610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  066850   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  048140   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  034010   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  054150   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  001670   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  003900   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  012410   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  091690   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  064420   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  008080   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  041060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  046430   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  053890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032050   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036360   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  054440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  003990   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  033330   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  012990   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  085450   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  003930   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036820   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  063510   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  035870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  019930   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  027350   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  006600   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  031150   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  049370   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  092630   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  039790   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  329560   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  347000   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  328380   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  151750   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  225650   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  242350   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  053320   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  312610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  180060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  234340   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  282880   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  319400   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  347860   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  256630   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  336260   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  092590   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  322310   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  153360   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  112240   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  315640   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  220630   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  335890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  288490   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  221610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  225330   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  323280   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  134780   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  163430   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  221800   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  016830   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  336370   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  376980   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  007630   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  404990   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  002550   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  377400   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  038160   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  217880   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  369370   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  397880   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  005280   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  005450   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  357580   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  060000   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  252990   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  376180   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  274090   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  176440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  006350   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  308080   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  333050   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  066110   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  006440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  223250   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  302440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  226350   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  006220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  001290   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  000060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  377450   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  253610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  025340   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  016610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  340120   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  016140   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  047730   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  052350   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  035210   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  010150   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  221200   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  223040   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  221950   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  016170   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  051170   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  047060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  167380   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  122050   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  999980   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  047440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  331520   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  284610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  081970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  277880   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  254120   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  347140   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  344050   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  056140   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  012400   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045880   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  030390   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  013650   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  026540   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  089240   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  035710   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  002540   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  086720   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  033720   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  078700   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  042870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  037510   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  013240   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  052310   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  017010   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032930   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  084160   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  047450   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045290   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  030420   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  051530   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  066060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  049000   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  008540   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036280   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  041030   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  123910   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  014300   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  078610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  073780   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  083160   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  057330   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  053170   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  004530   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  065810   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  073530   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  067910   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  055970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  012460   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  010200   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  043690   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  055810   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  037500   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  054370   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  027700   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  005560   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  011720   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  000830   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  042950   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  099660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  197210   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  307930   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  294630   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  124560   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  271780   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  241840   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  079560   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  366330   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  347700   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  258540   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  204270   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  103660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  164060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  323210   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  334970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  225850   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  321820   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  023890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  301300   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  110660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  329050   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  010090   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  073710   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032290   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  052270   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  103130   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  100790   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  318660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  031920   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  238170   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  396690   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  005980   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  281310   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  290090   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  270660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  004510   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  348950   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  317830   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  084850   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  307280   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  008270   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  172580   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  096300   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  039490   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  001970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  348370   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  383800   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  377220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032300   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  213090   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  289010   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  008340   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  357120   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  159010   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  179530   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  357250   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  286000   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  019590   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  338100   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  326030   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  152550   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  243870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  114570   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  333430   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  033600   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  169670   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  332370   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  031950   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  026230   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  067130   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  010460   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  072430   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  232360   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  260490   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  217810   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  062580   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  237720   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  039530   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  262760   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  179440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  271740   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  098400   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  251960   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  248070   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  217950   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  220250   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  002300   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  224760   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  297570   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  040130   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  037830   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  055250   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  022520   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  030030   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036270   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032030   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  065410   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  061050   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  039990   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032150   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  049690   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  052650   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032390   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045400   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  052970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  016160   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  093400   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  046720   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  004550   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  126680   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  080980   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  041630   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  123290   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  071660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  011800   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  080970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  065610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  124050   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  042820   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  013780   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  046810   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  080960   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  003330   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  065910   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  057110   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  016040   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  037060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  060410   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  037220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036020   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  053250   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  008030   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032180   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036880   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036600   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  002930   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  068870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  037620   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  058370   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  083360   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  083390   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  074130   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  034750   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  117930   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  007190   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  194610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  212310   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  016570   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  335870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  199870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  037640   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  323940   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  001490   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  331660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  012760   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  336570   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  247660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  138290   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  339770   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  001310   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  258050   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  258790   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  317240   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  347740   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  199820   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  294090   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  332290   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  317870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  070480   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  023760   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  308170   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  377300   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  003540   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  303360   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  046110   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  322190   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  030210   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  338220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  033660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  060300   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  379390   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  149010   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  403360   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  353810   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  140610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  062970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  361610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  377480   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032710   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  236340   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  340440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  055550   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  381970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  361570   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  001270   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  257720   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  267060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  052190   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  389030   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  058480   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  136660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  372910   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  101360   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  352820   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  000540   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  185190   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  001500   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  388790   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  336040   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  303530   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  187660   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  126870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  327610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  344860   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  337840   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  317320   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  051310   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  227420   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  331380   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  008560   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  084440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  354200   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  307070   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  337930   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  299480   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  044990   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  134000   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  038320   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  001300   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  207930   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  215750   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  083350   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  219580   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  252940   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  226850   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  095300   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  225440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  082220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  030950   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  026220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  232330   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  210610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  271400   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  083380   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  086220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  339950   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  347890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  083370   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  108790   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  152330   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  313760   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  236810   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  009280   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  035480   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  304840   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  348210   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  082640   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  310200   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  341310   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  317400   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  058690   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036790   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  004620   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045260   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  032380   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  046240   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  094950   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  007800   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  046320   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  067950   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  024870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  101790   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  088960   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  079340   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  052560   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045710   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  037150   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  015050   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  128910   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  010670   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045470   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  017160   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  081090   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  038720   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  028090   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  016890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  042570   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045310   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036900   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  041940   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  009890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  038960   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  088510   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  056020   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  048150   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  006750   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  047610   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  045920   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  031970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  025270   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  025850   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  302920   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  234070   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  066270   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  121060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  357780   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  208890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  356890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  199290   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  267320   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  335810   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  033630   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  264850   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  321550   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  165270   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  182690   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  195940   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  000360   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  310840   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  099430   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  054340   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  393210   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  322780   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  402340   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  265740   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  225220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  276730   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  224020   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  391060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  053740   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  310870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  329180   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  194510   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  322000   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  402420   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  004940   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  026870   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  138930   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  001890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  058970   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  391710   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  330860   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  308700   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  259960   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  195440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  000030   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  303030   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  365590   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  383220   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  024110   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  015350   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  254160   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  216280   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  311060   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  258250   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  380440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  297890   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  363250   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  386580   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  122830   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  225860   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  331920   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  036490   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  316140   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  300080   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  003690   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  007640   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  031990   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  323990   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  007330   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  079440   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  299030   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  317860   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  050320   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  224090   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  102000   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  099210   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  187770   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  052880   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  101380   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  233190   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  005620   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  222390   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  235090   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  008000   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  004130   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  168490   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  099830   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  077280   year: 2018
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
#
# 해당보고서가 없습니다:  242850   year: 2018
# ...
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  011160   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  045060   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  173940   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  005390   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  036810   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  040300   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  042420   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000670   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  192390   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  010120   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003410   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  060260   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  005160   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  013310   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  093050   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  089470   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  093190   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  014570   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  070080   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  035600   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  036000   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  041830   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  298870   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  024840   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  035610   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  054950   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  039870   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  365270   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  102260   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001360   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  050090   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  230980   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  036620   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  098460   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  032350   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  344820   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  400760   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  027740   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  233990   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  034120   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  138070   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  045510   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000430   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  214310   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  039860   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003350   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  036670   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003450   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  087730   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  024090   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  382840   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  058220   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000270   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  034830   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  047920   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000010   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  288330   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  192530   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  226340   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  033540   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  017940   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  013570   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000400   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  123860   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  039610   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  014820   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  101240   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  029780   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  043650   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  133820   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  112040   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  019660   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  106080   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  101060   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  021960   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  017180   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  101670   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  014100   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  011500   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  240340   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  294870   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  007720   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  065620   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  243070   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  092440   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  007680   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  088910   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  005070   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  036030   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  214270   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  095660   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  224880   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  009810   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  005850   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  085370   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  101170   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  031310   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  049720   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  069410   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  131180   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  002900   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  032040   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  171010   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  027580   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  096350   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  057050   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  017370   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  141020   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  010690   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  002240   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  094190   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  052690   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  222040   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  017390   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  139990   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  196450   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  038060   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  051500   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  158310   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  006910   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  114450   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  057680   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  137310   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  053350   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  095570   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  016100   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  219750   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001620   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001130   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  156100   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  047310   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  013000   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  214450   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  100660   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  330590   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  026040   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  053110   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  069960   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  084870   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  131760   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  080440   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  033200   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  065680   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  009780   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  067370   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  068290   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  037630   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  044440   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  010520   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  138440   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  215580   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  232290   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  061460   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  218710   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  219860   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  246830   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  090730   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  130960   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  024660   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  087220   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  007910   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  111610   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  247300   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  265920   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  026180   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  205290   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  094700   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  046840   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  033270   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  004870   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  215050   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003380   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  290510   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  270210   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  323350   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  163730   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  088980   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  290270   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  039440   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001430   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  014590   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  332570   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  214180   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  342550   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  060540   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001420   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  014790   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  208850   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  072130   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  290660   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001570   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  250030   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  250000   year: 2019
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  053290   year: 2019
# CPU times: user 4min 11s, sys: 28.4 s, total: 4min 39s
# Wall time: 11min 20s

# %% [markdown]
# df_org = df.copy()

# %% [markdown]
# df_org = df.copy()

# %% [markdown]
# df_backup= df.copy()

# %%
df_company2 = pd.DataFrame()
for stock_code in df_company.종목코드.unique():
    row = pd.DataFrame(dart.company(stock_code), index=[0])
    if row['status'].values=='000':   #status 100 일경우 안나오는 기업. 000이면 정상적으로 호출이 되는것.
        df_company2 = df_company2.append(row)
    else:
        print(stock_code)
        continue

# %% [markdown]
# #### 업종코드 api호출된 기업개황에 결합

# %%
df_company2['induty_code_cat'] = df_company2['induty_code'].astype(str).str[:2].astype(int)

df_industry_categorization[['range_start', 'range_end']] = df_industry_categorization[['range_start', 'range_end']].apply(pd.to_numeric, errors='coerce')
s = pd.IntervalIndex.from_arrays(df_industry_categorization.range_start,
                                 df_industry_categorization.range_end, 'both')
df_mapping_industry = df_company2.assign(industry = df_industry_categorization.set_index(s).loc[df_company2.induty_code_cat].산업대분류.values )[['corp_code', 'industry']]

# %%
df_company = df_company.merge(df_mapping_industry, left_on='고유번호', right_on='corp_code', how='left')

# %% [markdown]
# #### 공시자료에서 연결재무재표 중 영업이익, 자산총계, 매출만 사용

# %% [markdown]
# import sweetviz as sv
# analyze_report = sv.analyze(df_org)
# analyze_report.show_html('dart_report.html', open_browser=False)

# %%
import numpy as np
df['thstrm_amount'] = np.where(df['thstrm_amount']=='-', 0, df['thstrm_amount']  )    #'-' 가 금액으로 들어간경우 숫자 0으로 대체

# %%
df = df[((df.fs_div=='CFS') & (df.account_nm.str.contains('영업이익')) ) |
   ((df.fs_div=='CFS') & (df.account_nm.str.contains('자산총계')) ) |
   ((df.fs_div=='CFS') & (df.account_nm.str.contains('매출')) )
   ]

# %%
df = df[df.currency=='KRW']

# %% [markdown]
# ## 데이터 결합

# %%
df = df.pivot_table(index=['rcept_no',	'reprt_code',	'bsns_year',	'corp_code', 'stock_code'], 
               columns='account_nm'	, values='thstrm_amount', aggfunc=sum).fillna(0).reset_index()

# %%
df_employee = df_employee.groupby(["고유번호", "사업연도" ,"보고서코드", "법인명" ])[['정규직수', '합계', '연간급여총액']].sum().reset_index()

# %%
df_merged = df.merge(df_employee, how='inner', left_on=['bsns_year', 'corp_code'], right_on=['사업연도', '고유번호']) 
df_merged = df_merged.merge(df_company[['종목코드', 'industry', '주소', '시도', '시군구', '읍면동', '번지', '지역코드', '위도', '경도' ]], 
                how='left',   left_on ='stock_code', right_on='종목코드')
df_merged.rename(columns={"합계":"종업원수"}, inplace= True)

# %%
df_merged['연간평균급여'] = (df_merged.연간급여총액/df_merged.종업원수).fillna(0)

# %%
df_merged.rename(columns={"industry_x":"industry"}, inplace= True)

# %% [markdown]
# df_merged.head(2)

# %%
df_merged = df_merged[['rcept_no', 'bsns_year', '매출액', '영업이익', '자산총계', '고유번호','stock_code', '법인명', 'industry' , '정규직수', '종업원수', '연간평균급여',
                       '시도', '시군구', '읍면동', '번지', '지역코드', '위도', '경도' ]]
df_merged.rename(columns={'industry':'업종명'}, inplace=True, errors="ignore")

# %%
df_merged.연간평균급여 = df_merged.연간평균급여.replace([np.inf, -np.inf], 0)

# %% [markdown]
# cols =['매출액', '영업이익', '자산총계', '연간평균급여']
# for col in cols:
#     print(col)
#     df_merged[col] = df_merged[col].str.replace(',', '').apply(pd.to_numeric, errors='coerce').fillna(0)

# %%
df_merged[df_merged.stock_code=='003620']#['매출액']
# Out:
#             rcept_no bsns_year                매출액              영업이익 자산총계  \
# 796   20190401003283      2018  3,494,637,644,343   -65,275,806,226    0
# 2011  20200330002307      2019  3,704,793,546,043   -64,175,997,221    0
# 4294  20210323000883      2020  3,623,882,266,268  -281,905,360,065    0
#
#           고유번호 stock_code    법인명  업종명  정규직수  종업원수        연간평균급여  시도  시군구  읍면동  \
# 796   00138242     003620  쌍용자동차  NaN  4972  5003  8.868679e+07  경기  평택시  칠괴동
# 2011  00138242     003620  쌍용자동차  NaN  4972  5003  8.573556e+07  경기  평택시  칠괴동
# 4294  00138242     003620  쌍용자동차  NaN  4840  4869  6.538324e+07  경기  평택시  칠괴동
#
#        번지        지역코드         위도          경도
# 796   580  4122010400  37.028952  127.095083
# 2011  580  4122010400  37.028952  127.095083
# 4294  580  4122010400  37.028952  127.095083

# %%
table_name = 'dart_disclosure_reported'
sql_create = f"""
    CREATE TABLE {table_name} (
    rcept_no VARCHAR(100),
    bsns_year VARCHAR(4),
    stock_code VARCHAR(6) ,
    고유번호 VARCHAR(10) ,
    법인명 VARCHAR(100) ,
    업종명 VARCHAR(100) ,
    정규직수 int, 
    종업원수 int, 
    연간평균급여 bigint,
    매출액 bigint,
    영업이익 bigint,
    자산총계 bigint,
    시도	 VARCHAR(10),
    시군구	VARCHAR(10),
    읍면동	VARCHAR(20),
    번지	VARCHAR(20),
    지역코드	VARCHAR(10),
    위도	double,
    경도    double
    ) CHARSET=utf8;
"""

# %%
push_into_tableau_DB(df_merged,  AWS_KEY, AWS_SECRET, table_name , sql_create, replace=True)
# Out:
# rcept_no, bsns_year, 매출액, 영업이익, 자산총계, 고유번호, stock_code, 법인명, 업종명, 정규직수, 종업원수, 연간평균급여, 시도, 시군구, 읍면동, 번지, 지역코드, 위도, 경도 (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)

# %%
df_merged
# Out:
#             rcept_no bsns_year              매출액             영업이익  \
# 0     20180628000160      2018   26,486,287,918   -2,421,224,869
# 1     20180628000221      2018   13,689,574,860      378,892,285
# 2     20180629000180      2018   10,617,309,716   -1,125,362,235
# 3     20180629000420      2018  107,804,655,124   10,147,395,343
# 4     20180629000437      2018  492,941,408,564   17,149,669,339
# ...              ...       ...              ...              ...
# 4841  20220831001680      2020   30,443,293,632    2,121,292,624
# 4842  20220908000088      2018  372,059,611,808   33,942,609,831
# 4843  20220908000100      2019  364,973,001,111   16,610,715,303
# 4844  20220923000276      2020   53,365,357,987  -21,892,260,198
# 4845  20220930000523      2020  224,922,213,158    3,138,145,550
#
#                  자산총계      고유번호 stock_code    법인명  업종명  정규직수  종업원수  \
# 0      53,706,903,697  00378363     060310     3S  NaN    67    67
# 1      83,733,936,170  00241209     033200    모아텍  NaN   105   105
# 2      36,717,349,367  00155586     024850  피에스엠씨  NaN   274   275
# 3     235,954,858,759  00106614     092440   기신정기  NaN   407   413
# 4     492,848,698,913  00118008     018500   동원금속  NaN   683   684
# ...               ...       ...        ...    ...  ...   ...   ...
# 4841   51,118,782,194  00255433     042510  라온시큐어  NaN   189   198
# 4842  350,605,916,672  00456218     080160   모두투어  NaN  1089  1237
# 4843  334,585,105,230  00456218     080160   모두투어  NaN  1047  1158
# 4844  172,007,119,266  00530556     122640    예스티  NaN   239   239
# 4845  211,759,011,992  00147152     011320    유니크  NaN   512   574
#
#             연간평균급여  시도  시군구       읍면동      번지        지역코드         위도  \
# 0     4.897531e+07  서울  금천구       가산동  345-24  1154510100  37.472852
# 1     4.424355e+07  인천  남동구       구월동     292  2820010100  37.448752
# 2     0.000000e+00  경기  화성시  향남읍 구문천리     928  4159025925  37.084418
# 3     4.737300e+07  인천  남동구       논현동     439  2820011000  37.408791
# 4     6.815351e+07  경북  경산시   진량읍 양기리   330-1  4729025327  35.890239
# ...            ...  ..  ...       ...     ...         ...        ...
# 4841  4.815009e+07  서울  강남구       역삼동  646-15  1168010100  37.500713
# 4842  4.431043e+07  서울   중구     을지로1가   188-3  1114010400  37.565634
# 4843  4.441364e+07  서울   중구     을지로1가   188-3  1114010400  37.565634
# 4844  4.491632e+07  경기  평택시   진위면 마산리       0  4122031022  37.086498
# 4845  5.633285e+07  경남  김해시   진영읍 죽곡리    10-1  4825025032  35.288543
#
#               경도
# 0     126.883273
# 1     126.714593
# 2     126.908098
# 3     126.703613
# 4     128.826578
# ...          ...
# 4841  127.035193
# 4842  126.979433
# 4843  126.979433
# 4844  127.104186
# 4845  128.775014
#
# [4846 rows x 19 columns]

# %% [markdown]
# df_merged[df_merged.종업원수<=0]
