# %%
import OpenDartReader
from dotenv import load_dotenv
import os 
import pandas as pd

load_dotenv()
api_key =  os.environ.get('OpenDartReader_key')
dart = OpenDartReader(api_key)

AWS_KEY = os.environ.get('AWS_KEY')
AWS_SECRET = os.environ.get('AWS_SECRET')
tableau_key = os.environ.get('tableau_red')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 20)

# %%
def readFromPrestoDB(sql_command):
    ''' Hive DB에서 데이터 로딩 '''
    try:
        from pyhive import presto
        import pandas as pd

        presto_conn = presto.connect(
            host = "presto-internal.dp.zigbang.net",
            port = 80,
            username = "biglabred", catalog = "hive", schema = ""
        )

        df = pd.read_sql(sql_command, presto_conn)

        presto_conn.close()
        return df
    
    except:
        print('Failed to read data from hive DB')

# %%
def get_sql(AWS_KEY, AWS_SECRET, sql_command):
    import cryptocode
    import pymysql
    import s3fs
    # 암호화된 태블로 DB 접속키 로딩
    # 암호화된 태블로 DB 접속키 로딩
    fs = s3fs.S3FileSystem(anon=False, key=AWS_KEY, secret=AWS_SECRET)
    with fs.open("s3://zigbang-mlops/models/red/red_encrypted.txt", mode="r") as f:
        key = f.readline()

    conn = pymysql.connect(
        #host="biglab.c3svvjp5iqfn.ap-northeast-1.rds.amazonaws.com", port=3306,
        host="rds-red-w.zigbang.io", port=3306,
        user="zigbang_tableau", passwd=tableau_key, #cryptocode.decrypt(key, AWS_SECRET),
        db="tableau", charset="utf8"
    )
    cursor = conn.cursor() 
    cursor.execute(sql_command)
    result = pd.DataFrame(cursor.fetchall())

    num_fileds = len(cursor.description)
    field_names = [i[0] for i in cursor.description]
    result.columns = field_names

    conn.close()
        
    return result

# %%
def load_xml_to_dataframe(response, keyword):
    import bs4 as bs
    import urllib.request
    soup = bs.BeautifulSoup(response_xml,'xml')
    
    rows = soup.find_all(keyword)
    columns = rows[0].find_all()
    
    rowList = []
    nameList = []
    columnList = []

    rowsLen = len(rows)
    columnsLen = len(columns)

    for i in range(0, rowsLen):
        columns = rows[i].find_all()

        for j in range(0, columnsLen):
            if i == 0:
                nameList.append(columns[j].name) #header
            eachColumn = columns[j].text #value
            columnList.append(eachColumn)
        rowList.append(columnList)
        columnList = []    # 다음 row의 값을 넣기 위해 비워준다

    result = pd.DataFrame(rowList, columns=nameList)
    return result

# %%
def ExportDataFrameGspread(googlespread_link, sheetname, dataframe, AWS_KEY, AWS_SECRET):    
    import gspread
    from oauth2client.service_account import ServiceAccountCredentials
    import s3fs
    import numpy as np

    scope = ['https://spreadsheets.google.com/feeds',
     'https://www.googleapis.com/auth/drive']
    fs = s3fs.S3FileSystem(anon=False, key=AWS_KEY, secret=AWS_SECRET)
    key_file_name = "gspreadkey.json"
    fs.download(f"s3://zigbang-mlops/models/red/{key_file_name}", key_file_name)

    credentials = ServiceAccountCredentials.from_json_keyfile_name(key_file_name, scope)
    gc = gspread.authorize(credentials)
    spreadsheet_url= googlespread_link
    doc = gc.open_by_url(spreadsheet_url)

    worksheet = doc.worksheet(sheetname)
    worksheet.clear()  #clear selected worksheet before export data frame
    
    dataframe.replace([np.inf, -np.inf], np.nan, inplace=True)
    dataframe.fillna('', inplace=True)
    worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())
           
    if os.path.exists("gspreadkey.json"):
        os.remove("gspreadkey.json")

# %%
def push_into_tableau_DB(data, AWS_KEY, AWS_SECRET, table_name, sql_create, replace=False):
    import cryptocode
    import pymysql
    import s3fs
    
    # 암호화된 태블로 DB 접속키 로딩
    fs = s3fs.S3FileSystem(anon=False, key=AWS_KEY, secret=AWS_SECRET)
    with fs.open("s3://zigbang-mlops/models/red/red_encrypted.txt", mode="r") as f:
        key = f.readline()
    
    # 태블로 DB에 접속하는 코드
    tableau_conn = pymysql.connect(
        host="rds-red-w.zigbang.io", port=3306,
        user="zigbang_tableau", passwd=cryptocode.decrypt(key, AWS_SECRET),
        db="tableau", charset="utf8"
    )
    cur = tableau_conn.cursor()

    # table_name이 존재하는지 체크하는 코드
    exist = cur.execute(f"SHOW TABLES LIKE '{table_name}'")
    
    if not exist:
        # table_name이 없다면 data 기반으로 생성하는 코드
        cur.execute(sql_create)
        
    # NULL 데이터 처리
    data = data.where(pd.notnull(data),"")
    
    # run_date 추가
    #data["run_date"] = datetime.now(timezone('Asia/Seoul')).strftime("%Y-%m-%d %H:%M:%S")
    
    # Replace할 경우 기존 데이터 삭제
    if replace:
        cur.execute(f"DELETE FROM {table_name}")
    
    # 데이터를 INSERT 하는 코드
    columns = ", ".join(data.columns)
    values = '('+', '.join(['%s']*len(data.columns))+')'
    statement = "INSERT INTO " + table_name + " (" + columns + ") VALUES " + values
    insert = [tuple(x) for x in data.values]
    cur.executemany(statement, insert)
    
    # Commit 및 접속 종료
    cur.execute("COMMIT")
    tableau_conn.close()

# %%
def readFromGspread(googlespread_link, sheetname, AWS_KEY, AWS_SECRET):
    ''' 구글 스프레드시트에서 데이터 로딩 '''
    import gspread
    from oauth2client.service_account import ServiceAccountCredentials
    import s3fs
    
    scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
    fs = s3fs.S3FileSystem(anon=False, key=AWS_KEY, secret=AWS_SECRET)
    key_file_name = "gspreadkey.json"
    fs.download(f"s3://zigbang-mlops/models/red/{key_file_name}", key_file_name)
    #with fs.open("s3://zigbang-mlops/models/red/{key_file_name}}",key_file_name, mode="r") as f:
    #    key = f.readline()
    
    credentials = ServiceAccountCredentials.from_json_keyfile_name(key_file_name, scope)
    gc = gspread.authorize(credentials)
    spreadsheet_url= googlespread_link
    doc = gc.open_by_url(spreadsheet_url)
    
    df = pd.DataFrame.from_records(doc.worksheet(sheetname).get_all_values())
    
    df.columns = df.iloc[0]
    df = df[1:]
    
    import os
    os.remove(key_file_name)
              
    return df

# %% [markdown]
# ## 데이터 불러오기

# %% [markdown]
# #### 기업개요 및 주소 정보

# %%
df_company = readFromPrestoDB('''
select * from 
(
select "고유번호", "정식명칭", "영문명칭", "종목명", "종목코드","법인구분", "법인등록번호",
"사업자등록번호", "주소", "업종코드", "업종명", "설립일",
"결산월", "created_at", "updated_at" from hive.ods.biglab_disclosure_company_overview
where "법인등록번호" !=''  and  "종목코드" != ''
) X
left join 
(
select * from
hive.ods.biglab_disclosure_company_address 
) Y
on X."주소" = Y."주소" 
'''
)

#법인등록번호가 null값인 것은 해외소재주소지로 제외 
#종목코드가 있는 상장사로 필터

# %% [markdown]
# #### 기업 분류 기준

# %%
url_industry_categorization = 'https://docs.google.com/spreadsheets/d/1N8iOHx1M8PLqlGiA2tgOKl-AFoCNw3Ew9bwHMMhBIIU/edit#gid=201266420'
df_industry_categorization = readFromGspread(url_industry_categorization, '표준산업대분류', AWS_KEY, AWS_SECRET)
df_industry_categorization = df_industry_categorization[['산업대분류', 'range_start', 'range_end']]

#df_industry_categorization = readFromGspread(url_industry_categorization, '표준산업분류', AWS_KEY, AWS_SECRET) 
#df_industry_categorization  = df_industry_categorization.CODE.astype(str).str.zfill(2)

# %% [markdown]
# #### 직원현황 공시정보

# %%
df_employee = readFromPrestoDB('''
select * from  hive.ods.biglab_disclosure_business_report_employee_summary    
where "보고서코드" ='11011'                         
''')
cols = ['정규직수', '합계', '연간급여총액', '1인평균급여액']
df_employee[cols] = df_employee[cols].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# #### 사업보고서 공시 자료 api 호출 중. (추후 태블로 DB에서 가져올 예정)

# %% [markdown]
# df_financial_stat = readFromPrestoDB('''
# select * from hive.ods.biglab_disclosure_financial_statement
# where "재무제표종류"='재무상태표, 유동/비유동법-연결재무제표'  -- '재무상태표, 유동/비유동법-별도재무제표'
# and "보고서종류"='사업보고서'
# and "항목코드"='ifrs-full_Assets' or "항목코드"= 'ifrs_Assets' -- 자산총계
# ''')

# %%
# %%time

api_key =  os.environ.get('OpenDartReader_key')
dart = OpenDartReader(api_key)
df = pd.DataFrame()
for yr in range(2018, 2021):
    for stock_code in df_company.종목코드:
        try:
            row = dart.finstate(corp=stock_code, bsns_year=yr , reprt_code='11011')
            if  row.shape!=(0,0):  #013 :조회된 데이타가 없습니다 일 경우에는 쉐입이 (0,0) 이 됨..
                df = df.append(row)
            else:
                print("해당보고서가 없습니다: ",stock_code, "  year:", yr)
                continue 
        except:
            row = []
            continue
# Out:
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  037600   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  007490   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001950   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  114410   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  103150   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001190   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  076850   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  008400   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  051820   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  052210   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  064060   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  060670   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  063280   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  061140   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  047370   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  085680   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  033260   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  037550   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  009380   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  048460   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  025920   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  012090   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  122750   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  121910   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  081190   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  040020   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  081930   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  066300   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  080180   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  081200   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  025610   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  042340   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  005330   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  035270   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  036760   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  038410   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  054250   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  073470   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  025450   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  008780   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  038400   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  005890   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  037120   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  035910   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  144630   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  090980   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  090970   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  091000   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  090990   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  050050   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  083610   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  083600   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  083580   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  083570   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  083590   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  068150   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  081940   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  015110   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  081210   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  068760   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  103840   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  002620   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001060   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  235980   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  140290   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  037950   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  068930   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  059210   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  002700   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  217910   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  007390   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  241690   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  225530   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  049960   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  011700   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  201490   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  236200   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  126340   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  002870   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  244920   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  329020   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  019560   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  056190   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  036260   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  005900   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  006920   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  060240   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  042370   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  012250   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  237750   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  269620   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  009070   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  192650   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  021880   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  270520   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  192080   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  023450   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  092730   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  002390   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  119610   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  017650   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  005110   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  330350   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  306040   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  150440   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  214260   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  046390   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  348030   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  009760   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  271560   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  336060   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  114810   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  282690   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  170900   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  004100   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  395400   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  190650   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  078890   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  168330   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  025620   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  010780   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  078520   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  002460   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  006980   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001380   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  005810   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  228180   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  143540   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  257370   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  078340   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  139050   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  094170   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  089980   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  200780   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  053260   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  096760   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000140   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  068270   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  039740   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  144620   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001880   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  228670   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  035460   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  111820   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  314130   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  049080   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  216080   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  238090   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  191410   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  224060   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  058630   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  030000   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  101000   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  340360   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  033830   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  002210   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  106240   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  088290   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  018880   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  170030   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  024950   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  046310   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001200   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  033550   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  061970   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  050120   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  012450   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  072950   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  092190   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  114630   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  031980   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  222080   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  041190   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  079950   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  032850   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  052600   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  006800   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001460   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  053800   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  161580   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  126560   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  078070   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  021240   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  088390   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  032280   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  020000   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  353200   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  043590   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  361670   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  078350   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000180   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  032620   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  126600   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  241710   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  027830   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  214330   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  025820   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  006400   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  037460   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  019010   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  042670   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  054180   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  031820   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  090150   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  093640   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001040   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  104620   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  086960   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  068330   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  052790   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  007110   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000100   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  333620   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  081000   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  058110   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003580   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  004690   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  210120   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  187790   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  065060   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  082850   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  245620   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  002320   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  250060   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003070   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  222160   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  043290   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003090   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  267810   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  004080   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  078650   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  271940   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  373200   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  008830   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  044820   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  271850   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  097520   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  026890   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  001070   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  131100   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  141070   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  307870   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  007310   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  298000   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  114190   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  272290   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  347770   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  019300   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  198440   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  216400   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  076080   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  036840   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  008670   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  307750   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000700   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  091590   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  229000   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  039010   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  095610   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  298690   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  317120   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  238200   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  290520   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  047400   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  246720   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  028150   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  266470   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  237820   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003310   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  054620   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  045520   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  178780   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  131030   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003610   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  139670   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  176750   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  069110   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  000040   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  089230   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  200350   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  313750   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  066980   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  003240   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  086790   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  101680   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  017670   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  036170   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  101400   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  267980   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  020760   year: 2018
# {'status': '020', 'message': '사용한도를 초과하였습니다.'}
#
# 해당보고서가 없습니다:  051630   year: 2018

# %% [markdown]
# df_org = df.copy()

# %% [markdown]
# #### 업종코드 얻기위해 api 호출, 추후 기업개황 db테이블 완료되면 가져오게 해야함.

# %%
df_company2 = pd.DataFrame()
for stock_code in df_company.종목코드.unique():
    row = pd.DataFrame(dart.company(stock_code), index=[0])
    if row['status']!='100':
        df_company2 = df_company2.append(row)
    else:
        print(stock_code)
        continue

df_company2['induty_code_cat'] = df_company2['induty_code'].astype(str).str[:2]

# %% [markdown]
# #### 공시자료에서 연결재무재표 중 영업이익, 자산총계, 매출만 사용

# %%
df = df[((df.fs_div=='CFS') & (df.account_nm.str.contains('영업이익')) ) |
   ((df.fs_div=='CFS') & (df.account_nm.str.contains('자산총계')) ) |
   ((df.fs_div=='CFS') & (df.account_nm.str.contains('매출')) )
   ]

# %%
df = df[df.currency=='KRW']

# %% [markdown]
# ## 데이터 결합

# %%
df = df.pivot_table(index=['rcept_no',	'reprt_code',	'bsns_year',	'corp_code', 'stock_code'], 
               columns='account_nm'	, values='thstrm_amount', aggfunc=sum).reset_index()

# %%
df_employee = df_employee.groupby(["고유번호", "사업연도" ,"보고서코드", "법인명" ])[['정규직수', '합계', '연간급여총액']].sum().reset_index()
df_merged = df.merge(df_employee, how='inner', left_on=['bsns_year', 'corp_code'], right_on=['사업연도', '고유번호']) 
df_merged = df_merged.merge(df_company[['종목코드', '업종명', '주소', '시도', '시군구', '읍면동', '번지', '지역코드', '위도', '경도' ]], 
                how='left',   left_on ='stock_code', right_on='종목코드')

df_merged.rename(columns={"합계":"종업원수"}, inplace= True)

# %%
df_merged = df_merged[['rcept_no', 'bsns_year', 'account_nm', 'fs_nm', 'sj_nm', 'stock_code', 'corp_code', 'thstrm_amount', '법인명', '업종명' , '정규직수', '종업원수', '연간급여총액',
                       '시도', '시군구', '읍면동', '번지', '지역코드', '위도', '경도' ]]
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
table_name = 'dart_disclosure'
sql_create = f"""
    CREATE TABLE {table_name} (
    rcept_no VARCHAR(100),
    bsns_year VARCHAR(4),
    account_nm  VARCHAR(100),
    fs_nm VARCHAR(100),
    sj_nm VARCHAR(100),
    stock_code VARCHAR(6) ,
    corp_code VARCHAR(10),
    thstrm_amount bigint ,
    법인명 VARCHAR(100),
    업종명 VARCHAR(100),
    정규직수 int, 
    종업원수 int, 
    연간급여총액  bigint,
    시도	 VARCHAR(10),
    시군구	VARCHAR(10),
    읍면동	VARCHAR(20),
    번지	VARCHAR(20),
    지역코드	VARCHAR(10),
    위도	double,
    경도    double
    ) CHARSET=utf8;
"""

# %%
push_into_tableau_DB(df_merged,  AWS_KEY, AWS_SECRET, table_name , sql_create, replace=True)

# %%
df_company2['induty_code_cat'] = df_company2['induty_code'].astype(str).str[:2].astype(int)

# %%
s = pd.IntervalIndex.from_arrays(df_category_big.range_start,
                                 df_category_big.range_end, 'both')
df_company2.assign(industry = df_industry_categorization.set_index(s).loc[df_company2.induty_code_cat].산업대분류.values )

# %%
# Out:
#    status message corp_code               corp_name  \
# 0     000      정상  01063990                 (주)로보로보
# 0     000      정상  00442145                  (주)아바코
# 0     000      정상  01414936      에스케이제6호기업인수목적 주식회사
# 0     000      정상  01050738                 (주)솔트룩스
# 0     000      정상  00574611                 에스디엔(주)
# ..    ...     ...       ...                     ...
# 0     000      정상  00351630                 (주)세코닉스
# 0     000      정상  00544452  (주)이리츠코크렙기업구조조정부동산투자회사
# 0     000      정상  00608839                 (주)에이루트
# 0     000      정상  00449254               주식회사쎄트렉아이
# 0     000      정상  00307028               경남제약 주식회사
#
#                                   corp_name_eng     stock_name stock_code  \
# 0                            RoboRobo Co., Ltd.           로보로보     215100
# 0                                 AVACOCO.,LTD.            아바코     083930
# 0   SK NO.6 SPECIAL PURPOSE ACQUISITION COMPANY  에스케이제6호기업인수목적     340350
# 0                                   SALTLUX Inc           솔트룩스     304100
# 0                              SDN Company Ltd.            SDN     099220
# ..                                          ...            ...        ...
# 0                             SEKONIX CO., LTD.           세코닉스     053450
# 0                              E KOCREF CR-REIT         이리츠코크렙     088260
# 0                               Aroot Co., Ltd.           에이루트     096690
# 0                      SatrecInitiativeCo.,Ltd.          쎄트렉아이     099320
# 0                      KYUNG NAM PHARM.CO.,LTD.           경남제약     053950
#
#    ceo_nm corp_cls       jurir_no     bizr_no  \
# 0     최영석        K  1101115638741  1078841033
# 0     김광현        K  1701110166737  5038143827
# 0     송문규        E  1101117262936  2978101897
# 0     이경일        K  1101110301632  1028113061
# 0     최기혁        K  1101111020299  2078141182
# ..    ...      ...            ...         ...
# 0     박은경        K  1158110006449  1278112192
# 0     허승재        Y  1101113275959  1078667081
# 0    서문동군        K  1341110095394  1238177233
# 0     김이을        K  1601110091283  3148129846
# 0     홍상혁        K  1350110085255  1348142258
#
#                                 adres                   hm_url  \
# 0      서울특별시 강북구 도봉로54길 6 로보로보빌딩(미아동)       www.roborobo.co.kr
# 0                   대구 달서구 월암동 1107번지          www.avaco.co.kr
# 0           서울특별시 영등포구 국제금융로8길 31, 4층
# 0                   서울특별시 강남구 언주로 538         www.saltlux.com/
# 0            경기도 성남시 수정구 대왕판교로 1281 -            www.sdn-i.com
# ..                                ...                      ...
# 0              경기도 동두천시  평화로2862번길 28          www.sekonix.com
# 0                   서울특별시 강남구 삼성로 511
# 0                경기도 오산시  가장산업동로 28-6          www.aroot.co.kr
# 0   대전광역시 유성구  유성대로1628번길 21 (주)쎄트렉아이          www.satreci.com
# 0                 경상남도 의령군 동동리 1539-5  www.kyungnampharm.co.kr
#
#              ir_url         phn_no        fax_no induty_code    est_dt acc_mt  \
# 0                      02-909-5050   02-917-3511         289  20150209     12
# 0                     053-583-8150  053-588-9209       29272  20000116     12
# 0                     02-3773-9131                     66199  20191017     12
# 0                     02-2193-1600  02-6499-0092         582  19810817     12
# 0                      02-446-6691   02-446-6626        4659  19940318     12
# ..              ...            ...           ...         ...       ...    ...
# 0   www.sekonix.com   031-860-1000  031-860-1091         273  19881224     12
# 0                      02-787-0000  02-2112-0939       68112  20050726     06
# 0                    031-8077-5000  02-6252-8150       26329  20020408     12
# 0   www.satreci.com   042-365-7500  042-365-7549        3131  19991229     12
# 0                     02-3490-5105  02)3490-5129         212  19981229     12
#
#     induty_code_cat  industry
# 0                28     제 조 업
# 0                29     제 조 업
# 0                66  금융 및 보험업
# 0                58     정보통신업
# 0                46  도매 및 소매업
# ..              ...       ...
# 0                27     제 조 업
# 0                68      부동산업
# 0                26     제 조 업
# 0                31     제 조 업
# 0                21     제 조 업
#
# [2466 rows x 21 columns]
