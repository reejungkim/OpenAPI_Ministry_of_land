# %%
import OpenDartReader
from dotenv import load_dotenv
import os 

# load .env
load_dotenv()
api_key =  os.environ.get('OpenDartReader_key')

dart = OpenDartReader(api_key)

# [비바리퍼블리카] (송금서비스 토스로 유명한), 공시(감사보고서) 목록
df = dart.list('비바리퍼블리카', start='1900')

# %%
df
# Out:
#   corp_code corp_name stock_code corp_cls          report_nm        rcept_no  \
# 0  01212921   비바리퍼블리카                   E    반기보고서 (2022.06)  20220829000672
# 1  01212921   비바리퍼블리카                   E    주요사항보고서(유상증자결정)  20220825000567
# 2  01212921   비바리퍼블리카                   E    주요사항보고서(유상증자결정)  20220720000316
# 3  01212921   비바리퍼블리카                   E    분기보고서 (2022.03)  20220530000844
# 4  01212921   비바리퍼블리카                   E    사업보고서 (2021.12)  20220331003427
# 5  01212921   비바리퍼블리카                   E  연결감사보고서 (2020.12)  20210406000710
# 6  01212921   비바리퍼블리카                   E    감사보고서 (2020.12)  20210406000707
# 7  01212921   비바리퍼블리카                   E    감사보고서 (2019.12)  20200410003129
# 8  01212921   비바리퍼블리카                   E    감사보고서 (2018.12)  20190412002776
# 9  01212921   비바리퍼블리카                   E    감사보고서 (2017.12)  20180413001411
#
#     flr_nm  rcept_dt rm
# 0  비바리퍼블리카  20220829
# 1  비바리퍼블리카  20220825
# 2  비바리퍼블리카  20220720
# 3  비바리퍼블리카  20220530
# 4  비바리퍼블리카  20220331  연
# 5   삼일회계법인  20210406
# 6   삼일회계법인  20210406
# 7   삼일회계법인  20200410
# 8   삼일회계법인  20190412
# 9   삼일회계법인  20180413
