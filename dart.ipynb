# %%
import OpenDartReader
from dotenv import load_dotenv
import os 
import pandas as pd

load_dotenv()
api_key =  os.environ.get('OpenDartReader_key')

dart = OpenDartReader(api_key)

# [비바리퍼블리카] (송금서비스 토스로 유명한), 공시(감사보고서) 목록
#df = dart.list('강원에너지', start='2015')

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
# 단일회사 주요 계정 
df_finstate = dart.finstate(corp='003620', bsns_year=2020, reprt_code='11011')
df_finstate[df_finstate.account_nm.str.contains('자산')]
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 1   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 11  20210323000883      11011      2020  00138242     003620    OFS    재무제표
# 12  20210323000883      11011      2020  00138242     003620    OFS    재무제표
# 13  20210323000883      11011      2020  00138242     003620    OFS    재무제표
#
#    sj_div  sj_nm account_nm thstrm_nm      thstrm_dt      thstrm_amount  \
# 0      BS  재무상태표       유동자산    제 59 기  2020.12.31 현재    546,711,520,169
# 1      BS  재무상태표      비유동자산    제 59 기  2020.12.31 현재  1,221,917,050,523
# 11     BS  재무상태표       유동자산    제 59 기  2020.12.31 현재    550,861,850,930
# 12     BS  재무상태표      비유동자산    제 59 기  2020.12.31 현재  1,213,832,438,923
# 13     BS  재무상태표       자산총계    제 59 기  2020.12.31 현재  1,764,694,289,853
#
# ...

# %%
df_finstate
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 1   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 2   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 3   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 4   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 5   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 6   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 7   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 8   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 9   20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# 10  20210323000883      11011      2020  00138242     003620    CFS  연결재무제표
# ...

# %%
# 단일회사 전체 재무제표 
df = dart.finstate_all(corp='003620', bsns_year=2020 , fs_div='CFS' )
df[(df.sj_nm =='재무상태표') & (df.account_nm.str.contains("자산")) ]
# Out:
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
#           rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0   20210323000883      11011      2020  00138242     BS  재무상태표
# 1   20210323000883      11011      2020  00138242     BS  재무상태표
# 5   20210323000883      11011      2020  00138242     BS  재무상태표
# 6   20210323000883      11011      2020  00138242     BS  재무상태표
# 7   20210323000883      11011      2020  00138242     BS  재무상태표
# 8   20210323000883      11011      2020  00138242     BS  재무상태표
# 11  20210323000883      11011      2020  00138242     BS  재무상태표
# 12  20210323000883      11011      2020  00138242     BS  재무상태표
# 13  20210323000883      11011      2020  00138242     BS  재무상태표
# 15  20210323000883      11011      2020  00138242     BS  재무상태표
# 16  20210323000883      11011      2020  00138242     BS  재무상태표
# 17  20210323000883      11011      2020  00138242     BS  재무상태표
#
#                                   account_id account_nm account_detail  \
# ...

# %%
df[df.sj_nm =='포괄손익계산서' ]
# Out:
#           rcept_no reprt_code bsns_year corp_code sj_div    sj_nm  \
# 43  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 44  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 45  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 46  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 47  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 48  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 49  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 50  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 51  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 52  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 53  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 54  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# 55  20210323000883      11011      2020  00138242    CIS  포괄손익계산서
# ...

# %%
df[df.account_nm.str.contains('자산총계')]
# Out:
#           rcept_no reprt_code bsns_year corp_code sj_div  sj_nm    account_id  \
# 17  20210323000883      11011      2020  00138242     BS  재무상태표  -표준계정코드 미사용-
#
#    account_nm account_detail thstrm_nm  thstrm_amount frmtrm_nm  \
# 17       자산총계              -    제 59 기  1768628570692    제 58 기
#
#     frmtrm_amount bfefrmtrm_nm bfefrmtrm_amount ord currency thstrm_add_amount
# 17  2019207142717       제 57 기    2205642065884  18      KRW               NaN

# %%
import dart_fss as dart

# %% [markdown]
# corp_list = dart.get_corp_list()
# corp_list.corps

# %%
dart.list('00502410', start='2020')
# Out:
#    corp_code  corp_name stock_code corp_cls        report_nm        rcept_no  \
# 0   00502410  오릭스캐피탈코리아                   E  분기보고서 (2022.06)  20220816000307
# 1   00502410  오릭스캐피탈코리아                   E      [기재정정]일괄신고서  20220811000213
# 2   00502410  오릭스캐피탈코리아                   E        증권발행실적보고서  20220721000326
# 3   00502410  오릭스캐피탈코리아                   E      투자설명서(일괄신고)  20220720000267
# 4   00502410  오릭스캐피탈코리아                   E         일괄신고추가서류  20220720000256
# 5   00502410  오릭스캐피탈코리아                   E  사업보고서 (2022.03)  20220628000025
# 6   00502410  오릭스캐피탈코리아                   E        증권발행실적보고서  20220316000893
# 7   00502410  오릭스캐피탈코리아                   E      투자설명서(일괄신고)  20220315000698
# 8   00502410  오릭스캐피탈코리아                   E         일괄신고추가서류  20220315000553
# 9   00502410  오릭스캐피탈코리아                   E  분기보고서 (2021.12)  20220214000247
# 10  00502410  오릭스캐피탈코리아                   E  반기보고서 (2021.09)  20211112000380
# ...

# %%
dart.api.info.alot_matter('00502410', '2021', '11011')

# %% [markdown]
# # Open DART API KEY 설정
# dart.set_api_key(api_key=api_key)
# corp_list = dart.get_corp_list()

# %%
df.loc[df.report_nm.str.contains('사업보고서')]

# %%
df.loc[df.report_nm.str.contains('감사보고서')]

# %%
# [쿠팡] "연결감사보고서 (2019.12)" 20200414000766 (삼일회계법인)
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20200414000766
html_text = dart.document('20220325001327')#('20200414000766')
df_list = pd.read_html(html_text)

# %%
len(df_list) #해당 보고서에 있는 테이블 갯수

# %%
df_list[20]  #15번째 테이블

# %%
# 보고서 링크
for ix, row in df.iterrows():
    rcp_no = row['rcept_no']
    print(f'http://dart.fss.or.kr/dsaf001/main.do?rcpNo={rcp_no}')
# Out:
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20221013900078
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20221006000095
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20221005000130
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220901900114
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220901900113
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220822900054
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220812001000
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220810900050
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220810900047
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220704900366
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220701900107
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220531002806
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220525900284
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220524900517
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220524900515
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20220524900495
# ...

# %%
# 삼성전자 2021 재무제표 
dart.finstate('삼성전자', 2021)

# 전체 재무제표 (삼성전자 2021 전체 재무제표)
dart.finstate_all('005930', 2021)#.head()
# Out:
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
#            rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0    20220308000798      11011      2021  00126380     BS  재무상태표
# 1    20220308000798      11011      2021  00126380     BS  재무상태표
# 2    20220308000798      11011      2021  00126380     BS  재무상태표
# 3    20220308000798      11011      2021  00126380     BS  재무상태표
# 4    20220308000798      11011      2021  00126380     BS  재무상태표
# ..              ...        ...       ...       ...    ...    ...
# 181  20220308000798      11011      2021  00126380    SCE  자본변동표
# 182  20220308000798      11011      2021  00126380    SCE  자본변동표
# 183  20220308000798      11011      2021  00126380    SCE  자본변동표
# 184  20220308000798      11011      2021  00126380    SCE  자본변동표
# 185  20220308000798      11011      2021  00126380    SCE  자본변동표
#
#                                             account_id       account_nm  \
# ...

# %% [markdown]
# reprt_code
#
# 1분기보고서 : 11013
#
# 반기보고서 : 11012
#
# 3분기보고서 : 11014
#
# 사업보고서 : 11011

# %%
# 삼성전자 2021Q1 재무제표
dart.finstate('삼성전자', 2021, reprt_code='11013').head()
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 지정한 날짜의 공시목록 전체 (공시 시간 정보 포함)
dart.list_date_ex('2022-10-04').head()
# Out:
#              rcept_dt corp_cls corp_name        rcept_no  \
# 0 2022-10-04 19:13:00        코   한국테크놀로지  20221004900680
# 1 2022-10-04 19:11:00        코   한국테크놀로지  20221004900679
# 2 2022-10-04 19:04:00        코    SK6호스팩  20221004900676
# 3 2022-10-04 19:00:00        코   한국테크놀로지  20221004000391
# 4 2022-10-04 18:47:00        코    한창바이오텍  20221004900671
#
#                      report_nm   flr_nm rm
# 0                  타인에대한담보제공결정  한국테크놀로지  코
# 1  [기재정정]최대주주변경을수반하는주식담보제공계약체결  한국테크놀로지  코
# 2         주권매매거래정지 (상장폐지 사유발생)  코스닥시장본부  코
# 3     [기재정정]주요사항보고서(전환사채권발행결정)  한국테크놀로지
# 4            [기재정정]단일판매ㆍ공급계약체결   한창바이오텍  코

# %%
# 하위 문서(sub_docs), 첨부 문서(attach_doc_list)
rcp_no = '20220308000798' 
dart.sub_docs(rcp_no) # 하위 문서 제목과 URL
dart.sub_docs(rcp_no, match='감사의견')  # 제목이 잘 매치되는 순서로 소트
dart.attach_doc_list(rcp_no) # 첨부 문서(i.e. 감사보고서) 제목과 URL
dart.attach_doc_list(rcp_no, match='감사의의견서') # 제목이 잘 매치되는 순서로 소트
# Out:
#                         title  \
# 2  2022.03.08 내부감시장치에대한감사의의견서
# 1         2022.03.08 감사의감사보고서
# 0            2022.03.08 감사보고서
# 4          2022.03.08 연결감사보고서
# 5            2022.03.08 영업보고서
# 3    2022.03.08 내부회계관리제도운영보고서
# 6               2022.03.08 정관
#
#                                                  url
# 2  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 1  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 0  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 4  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 5  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 3  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
# 6  http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20...
